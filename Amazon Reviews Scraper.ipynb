# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \AppleWebKit/537.36 (KHTML, like Gecko) \Chrome/90.0.4430.212 Safari/537.36'}

product_links = []

for x in range(0,23):
    links = f'https://www.amazon.in/Apple-iPhone-13-Pro-256GB/product-reviews/B09G99BKK4/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={x}'
    product_links.append(links)
    
for links in product_links:
    r = requests.get(links)
    soup = BeautifulSoup(r.content)
    Review_Title = soup.find('div' , class_ = 'a-section a-spacing-none review-views celwidget')
    for title in Review_Title:
        Title = title.find('a' , class_ = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold')
        try:
            print(Title.text.strip())
        except:
            print(" ")
# Out:
#
# Pro series living up to it’s name
# A fab phone even post the release of 14 pro.
# Best phone instead iphone 14 plus
# Did not receive charger adapter please send otherwise how the phone can be changed
# Undoubtedly, best phone
# Best camera
# Superb😍
# Good and premium
# Delivery on Time , Good Packing, Original Product.
# Good
#
#
# Pro series living up to it’s name
# A fab phone even post the release of 14 pro.
# Best phone instead iphone 14 plus
# Did not receive charger adapter please send otherwise how the phone can be changed
# Undoubtedly, best phone
# Best camera
# Superb😍
# Good and premium
# Delivery on Time , Good Packing, Original Product.
# Good
#
#
# 100% Satisfied
# Best iPhone Pro version to go for !
# I liked
# Outstanding..!!
# One of the best iPhone
# SIMPLY SUPERB
# Good condition new and genuine phone..trustworthy retailer
# Awesome
# My stomach burns with the pain everyday. I miss my kidney.
# Great phone but very expensive!!
#
#
# As everyone knows
# ...

# %%
testlink = 'https://www.amazon.in/Apple-iPhone-13-Pro-256GB/product-reviews/B09G99BKK4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
r = requests.get(testlink)
soup = BeautifulSoup(r.content)
Review_Title = soup.find('div' , class_ = 'a-section a-spacing-none review-views celwidget')
for title in Review_Title:
    Title = title.find('a' , class_ = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold')
    try:
        print(Title.text.strip())
    except:
        print(" ")
# Out:
#
# Pro series living up to it’s name
# A fab phone even post the release of 14 pro.
# Best phone instead iphone 14 plus
# Did not receive charger adapter please send otherwise how the phone can be changed
# Undoubtedly, best phone
# Best camera
# Superb😍
# Good and premium
# Delivery on Time , Good Packing, Original Product.
# Good

# %%
print(Review_Title)
# Out:
# From India
# Karthik Sundaresan5.0 out of 5 stars
# Pro series living up to it’s name
# Reviewed in India 🇮🇳 on 8 October 2022Size name: 128GBColour: GraphiteVerified Purchase
# ...
